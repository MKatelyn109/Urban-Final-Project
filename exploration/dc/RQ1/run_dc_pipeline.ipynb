# %%
# --- Step 1: Setup and Load Data ---

# Core libraries
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 120)

# --- Load Capital Bikeshare Data ---
# Replace with your local path or URL
bike_path = "../../Data/sample_dc_bikeshare/SAMPLE_DC_BIKE.csv"
bike = pd.read_csv(bike_path)

# Inspect structure
print("Bikeshare data shape:", bike.shape)
print(bike.head())

# --- Load Pedestrian & Cycle Counts Data ---
ped_path = "../../Data/sample_dc_foot/dc_foot_data.csv"
ped = pd.read_csv(ped_path)

print("\nPedestrian data shape:", ped.shape)
print(ped.head())
# Out:
# /var/folders/sv/zvgz0srn50j04884rgqy4z000000gn/T/ipykernel_81059/4096271929.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   bike = pd.read_csv(bike_path)
# Bikeshare data shape: (2749881, 14)
#             ride_id  rideable_type           started_at             ended_at             start_station_name  \
# 0  13A48BD20CC3DD85   classic_bike  2021-01-08 17:58:48  2021-01-08 18:25:23   Connecticut Ave & Yuma St NW
# 1  CA68C580B32EEE66  electric_bike  2021-01-08 22:05:51  2021-01-08 22:23:52                  8th & D St NW
# 2  5A925307814D5C2B   classic_bike  2021-01-21 17:20:31  2021-01-21 17:23:24  Wilson Blvd. & N. Vermont St.
# 3  B6B2DB54A2B233EE   classic_bike  2021-01-28 10:06:30  2021-01-28 10:20:54  Franklin St & S Washington St
# 4  921A142D5C8A9759   classic_bike  2021-01-11 12:09:45  2021-01-11 12:20:15      St. Asaph & Montgomery St
#
#   start_station_id               end_station_name end_station_id  start_lat  start_lng    end_lat    end_lng  \
# 0          31318.0    Georgia Ave & Emerson St NW        31405.0  38.947156 -77.065115  38.949662 -77.027333
# 1          31270.0                 14th & D St SE        31663.0  38.894804 -77.023091  38.884053 -76.986043
# 2          31926.0  George Mason Dr & Wilson Blvd        31036.0  38.879477 -77.114563  38.878870 -77.120700
# 3          31907.0              Braddock Rd Metro        31047.0  38.798133 -77.048700  38.814577 -77.052808
# 4          31931.0              Braddock Rd Metro        31047.0  38.814185 -77.043809  38.814577 -77.052808
#
#   member_casual                           source_file
# 0        casual  202101-capitalbikeshare-tripdata.csv
# 1        member  202101-capitalbikeshare-tripdata.csv
# 2        member  202101-capitalbikeshare-tripdata.csv
# 3        member  202101-capitalbikeshare-tripdata.csv
# 4        casual  202101-capitalbikeshare-tripdata.csv
#
# Pedestrian data shape: (404766, 5)
#    Unnamed: 0          Hour of Datetime                                Station  Counts       Datetime
# 0           0  October 6, 2017 at 11 AM  Wharf Classic - Maine Ave Cycle Track       9  10/6/17 11:00
# 1           1  October 6, 2017 at 12 PM  Wharf Classic - Maine Ave Cycle Track       3  10/6/17 12:00
# 2           2   October 6, 2017 at 1 PM  Wharf Classic - Maine Ave Cycle Track       7  10/6/17 13:00
# 3           3   October 6, 2017 at 2 PM  Wharf Classic - Maine Ave Cycle Track       7  10/6/17 14:00
# 4           4   October 6, 2017 at 3 PM  Wharf Classic - Maine Ave Cycle Track       7  10/6/17 15:00

# %%
from bikeshare_pedestrian_analysis import main
# =============================================================================
# Run analysis - pedestrian coords are built-in!
# =============================================================================
analyzer = main(bike, ped, distance_threshold=800)

# =============================================================================
# Access results
# =============================================================================
print("\n" + "="*70)
print("RESULTS SUMMARY")
print("="*70)

# Correlation results
print(f"\nAnalyzed {len(analyzer.correlation_results)} pedestrian locations")
print(f"Mean correlation: {analyzer.correlation_results['pearson_r'].mean():.3f}")
print(f"Median correlation: {analyzer.correlation_results['pearson_r'].median():.3f}")

# Top 5 correlations
print("\nTop 5 strongest correlations:")
top5 = analyzer.correlation_results.nlargest(5, 'pearson_r')
for _, row in top5.iterrows():
    print(f"  {row['ped_station'][:50]:50s} r={row['pearson_r']:.3f}")
# Out:
# Cleaning bikeshare data...
# Bikeshare data cleaned: 2416630 trips
# Cleaning pedestrian data...
# Pedestrian data cleaned: 404766 observations
#
# Processing station coordinates...
# Loaded 1538 cached geocodes
#
# Creating spatial matches (threshold: 800m)...
#   Bikeshare stations with coordinates: 1520
#   Pedestrian counters with coordinates: 18
#   Found 276 spatial matches
#     16 pedestrian stations matched
#     89 bikeshare stations matched
#
#   Example matches:
#     Wharf Classic - Maine Ave Cycle Track    <-> 4th & M St SW                            (553m)
#     Wharf Classic - Maine Ave Cycle Track    <-> L'Enfant Plaza / 7th & C St SW           (585m)
#     Wharf Classic - Maine Ave Cycle Track    <-> 4th & C St SW                            (658m)
#
# Computing correlations...
#
# Aggregating bikeshare data to hourly resolution...
#   Created hourly aggregation: 1515397 station-hour combinations
#
# Correlation analysis complete for 7 locations
#
# Saved correlation summary plot to RQ1_PLOTS/correlation_summary.png
#
# ======================================================================
# GENERATING ACADEMIC ANALYSIS ADDITIONS
# ======================================================================
#
# Saved spatial correlation map to RQ1_PLOTS/spatial_correlation_map.png
#
# Saved location type analysis to RQ1_PLOTS/location_type_analysis.png
#
# Kruskal-Wallis Test: H=3.143, p=0.2077
#   → No significant difference between location types
#
# Saved statistical summary table to RQ1_PLOTS/statistical_summary_table.csv
#
# ====================================================================================================
# STATISTICAL SUMMARY TABLE
# ====================================================================================================
#           Pedestrian Counter Location       Type       n_obs Mean_Ped_Count Mean_Bike_Trips     Pearson_r p_value      Sig n_Bike_Stations
# Wharf Classic - Maine Ave Cycle Track Waterfront        6524           18.4            25.4         0.797     0.0      ***              27
#                            11th St NW     Street        6553            7.1            64.6         0.628     0.0      ***              56
#       Anacostia River Trail - Benning Trail/Park        1160           46.4             3.1         0.412     0.0      ***               8
#                        Columbia Rd NW     Street        7465           12.2            24.3         0.275     0.0      ***              38
#                            14th St NW     Street        6826            6.9            47.7         0.261     0.0      ***              45
#     Anacostia River Trail - Deane Ave Trail/Park        1002           38.0             1.3         0.105  0.0008      ***               3
#       Anacostia River Trail - 11th St Trail/Park         241          510.1             2.0         0.052   0.426                       10
#                   OVERALL (Mean ± SD)        All 4253 ± 3256   91.3 ± 185.3     24.0 ± 24.6 0.362 ± 0.272       - 6/7 sig.     26.7 ± 20.5
#
# Note: *** p<0.001, ** p<0.01, * p<0.05
# ====================================================================================================
#
# ============================================================
# CORRELATION ANALYSIS SUMMARY
# ============================================================
#
# Dataset Overview:
#   Bikeshare trips: 2,416,630
#   Pedestrian observations: 404,766
#   Spatial matches: 276
#   Locations analyzed: 7
#
# Correlation Statistics:
#   Mean Pearson r: 0.362
#   Median Pearson r: 0.275
#   Std Pearson r: 0.272
#
#   Statistically significant (p<0.05): 6/7
#   Positive correlations: 7/7
#   Strong correlations (|r|>0.5): 2/7
#
# Top 5 Strongest Positive Correlations:
#   Wharf Classic - Maine Ave Cycle Track    r=0.797 (p=0.0000)
#   11th St NW                               r=0.628 (p=0.0000)
#   Anacostia River Trail - Benning          r=0.412 (p=0.0000)
#   Columbia Rd NW                           r=0.275 (p=0.0000)
#   14th St NW                               r=0.261 (p=0.0000)
#
# Interpretation:
#   Moderate positive relationship between pedestrian traffic and bikeshare usage
#
# ============================================================
#
# ======================================================================
# RESULTS SUMMARY
# ======================================================================
#
# Analyzed 7 pedestrian locations
# Mean correlation: 0.362
# Median correlation: 0.275
#
# Top 5 strongest correlations:
#   Wharf Classic - Maine Ave Cycle Track              r=0.797
#   11th St NW                                         r=0.628
#   Anacostia River Trail - Benning                    r=0.412
#   Columbia Rd NW                                     r=0.275
#   14th St NW                                         r=0.261
#
# ======================================================================
# ALL OUTPUTS SAVED TO /mnt/user-data/outputs/
# ======================================================================
#
# Visualizations:
#   1. correlation_summary.png - 4-panel overview
#   2. spatial_correlation_map.png - Map showing where correlations occur
#   3. location_type_analysis.png - Trails vs Streets comparison
#
# Data Tables:
#   4. statistical_summary_table.csv - Full results table for your paper
#   5. correlation_results.csv - Raw correlation data
#   6. spatial_matches.csv - Station pairings
#
# Use these in your academic paper!
# ======================================================================
